# %%
# %matplotlib notebook 
import numpy as np
import matplotlib.image as im
import matplotlib.pyplot as plt

I=im.imread('pomme.jpeg')
print(I)
plt.imshow(I, cmap='gray')
# Out:
# [[149 152 156 ...  74  74  74]
#  [157 159 161 ...  74  74  74]
#  [165 167 168 ...  74  74  74]
#  ...
#  [192 192 192 ... 190 188 187]
#  [192 192 192 ... 190 188 187]
#  [192 192 192 ... 190 188 187]]
# <img src="data:image/png;base64,..." width="638">

# %%
print(I.shape)
A=I/2
print(A)
plt.imshow(A)
# Out:
# (1204, 1880)
# [[74.5 76.  78.  ... 37.  37.  37. ]
#  [78.5 79.5 80.5 ... 37.  37.  37. ]
#  [82.5 83.5 84.  ... 37.  37.  37. ]
#  ...
#  [96.  96.  96.  ... 95.  94.  93.5]
#  [96.  96.  96.  ... 95.  94.  93.5]
#  [96.  96.  96.  ... 95.  94.  93.5]]
