# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2*np.pi, 1000)
cos_x=np.cos(x)
sin_x=np.sin(x)

step=0.10
for percent in np.arange(1, 0, -step):
    plt.plot(cos_x*(1+(1-percent)/4), sin_x*percent)

plt.show()
