# %%
#QUESTION 1
import numpy as np
import matplotlib.image as im
import matplotlib.pyplot as plt

a=np.random.randint(256, size=(128,128))
b=np.random.randint(256, size=(128,128))
c=np.random.randint(256, size=(128,128))
d=np.random.randint(256, size=(128,128))
e=np.random.randint(256, size=(128,128))
f=np.random.randint(256, size=(128,128))
g=np.random.randint(256, size=(128,128))
h=np.random.randint(256, size=(128,128))
i=np.random.randint(256, size=(128,128))

imgs=[a, b, c, d, e, f, g, h, i]

# %%
# %matplotlib notebook 

plt.subplot(331)
plt.title('a')
plt.imshow(a, cmap='gray')

plt.subplot(332)
plt.title('b')
plt.imshow(b, cmap='gray')

plt.subplot(333)
plt.title('c')
plt.imshow(c, cmap='gray')

plt.subplot(334)
plt.title('d')
plt.imshow(d, cmap='gray')

plt.subplot(335)
plt.title('e')
plt.imshow(e, cmap='gray')

plt.subplot(336)
plt.title('f')
plt.imshow(f, cmap='gray')

plt.subplot(337)
plt.title('g')
plt.imshow(g, cmap='gray')

plt.subplot(338)
plt.title('h')
plt.imshow(h, cmap='gray')

plt.subplot(339)
plt.title('i')
plt.imshow(i, cmap='gray')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638">

# %%
#QUESTION 3
# %matplotlib notebook
def moy(imgs):
    img_moy=np.zeros(imgs[0].shape)
    for curr_img in imgs:
        img_moy=img_moy+curr_img
    img_moy=img_moy/len(imgs)
    return img_moy


img_moy = moy(imgs)
plt.title('Image moyenne')
plt.imshow(img_moy, cmap='gray')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638">

# %%
#QUESTION 4
# %matplotlib notebook
L=im.imread('Lenna.png')
plt.imshow(L)
# Out:
# [[[0.8862745  0.5372549  0.49019608]
#   [0.8862745  0.5372549  0.49019608]
#   [0.8745098  0.5372549  0.52156866]
#   ...
#   [0.9019608  0.5803922  0.47843137]
#   [0.8666667  0.50980395 0.43137255]
#   [0.78431374 0.3882353  0.3529412 ]]
#
#  [[0.8862745  0.5372549  0.49019608]
#   [0.8862745  0.5372549  0.49019608]
#   [0.8745098  0.5372549  0.52156866]
#   ...
#   [0.9019608  0.5803922  0.47843137]
#   [0.8666667  0.50980395 0.43137255]
#   [0.78431374 0.3882353  0.3529412 ]]
#
#  [[0.8862745  0.5372549  0.49019608]
#   [0.8862745  0.5372549  0.49019608]
#   [0.8745098  0.5372549  0.52156866]
#   ...
#   [0.9019608  0.5803922  0.47843137]
#   [0.8666667  0.50980395 0.43137255]
#   [0.78431374 0.3882353  0.3529412 ]]
#
#  ...
#
#  [[0.32941177 0.07058824 0.23529412]
#   [0.32941177 0.07058824 0.23529412]
#   [0.36078432 0.10588235 0.22745098]
#   ...
#   [0.6784314  0.28627452 0.32941177]
#   [0.6745098  0.26666668 0.29803923]
#   [0.69411767 0.24313726 0.30980393]]
#
# ...

# %%
#QUESTION 5
M=[]

for index in range(10):
    M.append(np.random.randint(256, size=(L.shape)))

# %%
#QUESTION 6
J=[]

for index in range(10):
    J.append(L+M[index])

# %%
#QUESTION 7
# %matplotlib notebook

J_moy = moy(J)
plt.title('Image moyenne des J')
plt.imshow(img_moy)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638">
# [[[ 96.08627452 151.03725493 112.69019608]
#   [117.58627452 152.73725493 122.79019608]
#   [146.57450981 137.43725493 136.72156866]
#   ...
#   [ 97.10196079 118.48039218 145.77843137]
#   [103.06666667 138.20980395 118.63137255]
#   [132.98431374 123.7882353  152.65294119]]
#
#  [[141.58627452 153.53725493 141.69019608]
#   [150.08627452 137.23725493 110.79019608]
#   [107.77450981 131.83725493 133.02156866]
#   ...
#   [152.10196079 166.68039218 149.47843137]
#   [145.96666667 118.70980395 109.03137255]
#   [165.28431374 120.4882353  136.85294119]]
#
#  [[152.18627452 111.53725493 165.29019608]
#   [161.98627452 139.53725493 113.19019608]
#   [174.57450981 109.53725493  99.02156866]
#   ...
#   [122.40196079 128.28039218 119.27843137]
#   [119.66666667 162.90980395 168.53137255]
#   [143.38431374 114.8882353  117.75294119]]
#
#  ...
#
#  [[116.02941177 126.97058824 141.93529412]
#   [153.82941177 110.87058824  97.23529412]
# ...
