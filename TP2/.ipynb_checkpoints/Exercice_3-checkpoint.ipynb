# %%
# %matplotlib notebook 
import numpy as np
import matplotlib.image as im
import matplotlib.pyplot as plt

I=im.imread('pomme.jpeg')
print(I)
plt.imshow(I, cmap='gray') #On lui précise comment interpreter le seul canal décrit dans l'image
# Out:
# [[149 152 156 ...  74  74  74]
#  [157 159 161 ...  74  74  74]
#  [165 167 168 ...  74  74  74]
#  ...
#  [192 192 192 ... 190 188 187]
#  [192 192 192 ... 190 188 187]
#  [192 192 192 ... 190 188 187]]
# <img src="data:image/png;base64,..." width="638">

# %%
# %matplotlib notebook 
print("Taille de l'image I :", I.shape)
verif_I=True
for i in range(I.shape[0]):
    for j in range(I.shape[1]):
        if I[i][j]>255:
            verif_I=False
            break
if not verif_I:
    print("L'image n'est pas en niveau de gris")
else:
    print("L'image est en niveau de gris")
# Out:
# Taille de l'image I : (1204, 1880)
# L'image est en niveau de gris

# %%
#QUESTION 5
print("I =", I)
I=I.reshape((I.shape[0])*(I.shape[1]), 1)
print("I en colonne:", I)
# Out:
# I = [[149 152 156 ...  74  74  74]
#  [157 159 161 ...  74  74  74]
#  [165 167 168 ...  74  74  74]
#  ...
#  [192 192 192 ... 190 188 187]
#  [192 192 192 ... 190 188 187]
#  [192 192 192 ... 190 188 187]]
# I en colonne: [[149]
#  [152]
#  [156]
#  ...
#  [190]
#  [188]
#  [187]]

# %%
#QUESTION 6
# %matplotlib notebook

I_hist=I.reshape(1, (I.shape[0])*(I.shape[1]))[0].copy()
print("I_hist :", I_hist)

plt.hist(I_hist, density=True,color='m')
# Out:
# I_hist : [149 152 156 ... 190 188 187]
# <img src="data:image/png;base64,..." width="638">
# (array([1.08229833e-04, 2.29635397e-03, 4.73373417e-03, 5.61246270e-03,
#         8.10025891e-03, 8.08901492e-03, 6.89578404e-03, 3.24738010e-03,
#         1.20634597e-04, 1.18330360e-05]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <BarContainer object of 10 artists>)

# %%
#QUESTION 7
I_hist = I_hist-np.mean(I_hist)
print("I_hist :", I_hist)
# Out:
# I_hist : [27.77489176 30.77489176 34.77489176 ... 68.77489176 66.77489176
#  65.77489176]

# %%
#QUESTION 8
# %matplotlib notebook
plt.hist(I_hist, density=True,color='m')
# Out:
# <img src="data:image/png;base64,..." width="638">
# (array([1.08229833e-04, 2.29635397e-03, 4.73373417e-03, 5.61246270e-03,
#         8.10025891e-03, 8.08901492e-03, 6.89578404e-03, 3.24738010e-03,
#         1.20634597e-04, 1.18330360e-05]),
#  array([-121.22510824,  -95.72510824,  -70.22510824,  -44.72510824,
#          -19.22510824,    6.27489176,   31.77489176,   57.27489176,
#           82.77489176,  108.27489176,  133.77489176]),
#  <BarContainer object of 10 artists>)

# %%
#QUESTION 9
#On se ramene à une loi normale centrée reduite de moyenne ou 8% des valeus sont proches de la moyenne ???
